# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("mxmh_survey_results.csv")
df.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages  ...  Frequency [R&B]  Frequency [Rap] Frequency [Rock]  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Gráfico 1: Indíce de depressão por idade

# %%
sns.lineplot(data = df, x = 'Age', y = 'Depression')

plt.title('Indíce de depressão por idade')
plt.xlabel('Idade')
plt.ylabel('')
plt.show()

# %% [markdown]
# Gráfico 2: Serviços de streaming mais ouvidos

# %%
df['Primary streaming service'].value_counts()
servicos.plot(kind='bar')

plt.title('Streamings mais ouvidos')
plt.xlabel('Streamings')
plt.ylabel('Mais ouvidos')
plt.show()

# %% [markdown]
# Gráfico 3: Indíce de pessoas que ouvem música no trabalho para melhorar a saúde mental

# %%
plt.pie(df['While working'].value_counts(), labels = df['While working'].value_counts().index, autopct = '%.001f%%')

plt.title('Indíce de pessoas que ouvem música no trabalho para melhorar a saúde mental')
plt.legend(title = "Legenda", bbox_to_anchor = (1,1))
plt.show()

# %% [markdown]
# Gráfico 4: Distribuição dos efeitos da música na depressão

# %%
data1 = df[df['Anxiety']>0]
sns.countplot(data=data1, x='Fav genre', hue='Music effects')
plt.title('Distribuição dos efeitos da música na depressão')
plt.xlabel('Gêneros musicais')
plt.ylabel('Distribuição dos efeitos da música')
plt.xticks(rotation = 90)
plt.show()
